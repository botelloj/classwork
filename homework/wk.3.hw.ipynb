# %%
x = 8
y = 12
result = x > 5 and y < 10
print(result)
# Out:
# False

# %%
my_list = [1, 2, 3, 4, 5]
a = 3 
b = 6 
if a and b in my_list:
    print("Both a and b are in my list")
elif a in my_list:
    print("a is in my_list")
elif b in my_list:
    print("b is in my list")
else:
    print("neither a or b are in my_list")
# Out:
# a is in my_list

# %%
my_list = []
if my_list:
    print("List has items")
else: 
    print("List is empty")
# Out:
# List is empty
