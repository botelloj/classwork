# %%
name = "Jessenia"
age = 20
grade = 100.0
is_student = True
favorite_color = "green"

print("name:", name)
print("age:", age)
print("grade:", grade)
print("is a student:", is_student)
print("favorite color:", favorite_color)
# Out:
# name: Jessenia
# age: 20
# grade: 100.0
# is a student: True
# favorite color: green

# %%
name = str("Jessenia")
age = int(20)
grade = float(100.0)
is_student = bool(True)
favorite_color = str("green")

# %%
print("capitalized:", name.upper())
# Out:
# capitalized: JESSENIA

# %%
sum = age + grade

print(age + grade)
print(type(sum))
# Out:
# 120.0
# <class 'float'>

# %%
dict_person = {
    "name": str("Jessenia"),
    "age": int(20),
    "grade": float(100.0),
    "is_student": bool(True),
    "favorite_color": str("green")
}

print("person:", dict_person)
# Out:
# person: {'name': 'Jessenia', 'age': 20, 'grade': 100.0, 'is_student': True, 'favorite_color': 'green'}

# %%
print(f"My name is {dict_person["name"]}. I am {dict_person["age"]} years old. My favorite color is {dict_person["favorite_color"]}. I will get a {dict_person["grade"]} in this class.")
# Out:
# My name is Jessenia. I am 20 years old. My favorite color is green. I will get a 100.0 in this class.
